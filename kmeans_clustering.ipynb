# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
#1.Sahte veri kümesi oluşturulur.
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)

# %%
kmeans=KMeans(n_clusters=4)

# %%
kmeans.fit(X)
# Out:
# /home/seymaaksu/anaconda3/envs/opencv_env/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4)

# %%
labels=kmeans.labels_

# %%
score = silhouette_score(X,labels)

# %%
print(score)
# Out:
# 0.8756469540734731

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.title("K-Means Kümeleme + Merkezler")
plt.show()

# %%
kmeans=KMeans(n_clusters=6)
kmeans.fit(X)
# Out:
# /home/seymaaksu/anaconda3/envs/opencv_env/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=6)

# %%
labels=kmeans.labels_

# %%
score =  silhouette_score(X,labels)
print(score)
# Out:
# 0.5853234594447899

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.title("K-Means Kümeleme + Merkezler")
plt.show()

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# /home/seymaaksu/anaconda3/envs/opencv_env/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=2)

# %%
labels=kmeans.labels_

# %%
score =  silhouette_score(X,labels)
print(score)
# Out:
# 0.6154853461594691

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.title("K-Means Kümeleme + Merkezler")
plt.show()

# %%
#1.Sahte veri kümesi oluşturulur. Elbow Yöntemi için
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)

# %%
wcss = [] 
K = range(1, 10)

for k in K:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
# Elbow grafiğini çiz
plt.plot(K, wcss, 'bo-')
plt.xlabel('Küme Sayısı (k)')
plt.ylabel('WCSS (Inertia)')
plt.title('Elbow Yöntemi - Küme Sayısı Seçimi')
plt.xticks(K)
plt.show()
